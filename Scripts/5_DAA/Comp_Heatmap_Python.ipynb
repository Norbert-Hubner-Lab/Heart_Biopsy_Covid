# %%
import scanpy as sc

# %%
x = sc.read_h5ad("/GLOBAL.h5ad")

# %%
x.obs['celltype_classified'].cat.categories
# Out:
# Index(['Adipo', 'CM', 'EC', 'Fib', 'Lymph', 'Mast', 'Mural', 'Myel', 'Neuro',
#        'PKHD1L1+ EC', 'unassigned'],
#       dtype='object')

# %%
sc.pl.umap(x, 
          color="celltype_classified")

# %%
[print("'", i,"'","=","'",j,"'") for i,j in zip(x.obs['celltype_classified'].cat.categories, x.uns['celltype_classified_colors'])]
# Out:
# ' Adipo ' = ' #1f77b4 '
# ' CM ' = ' #ff7f0e '
# ' EC ' = ' #279e68 '
# ' Fib ' = ' #d62728 '
# ' Lymph ' = ' #aa40fc '
# ' Mast ' = ' #8c564b '
# ' Mural ' = ' #e377c2 '
# ' Myel ' = ' #b5bd61 '
# ' Neuro ' = ' #17becf '
# ' PKHD1L1+ EC ' = ' #aec7e8 '
# ' unassigned ' = ' #ffbb78 '
# [None, None, None, None, None, None, None, None, None, None, None]

# %%
x.obs.to_csv("/GLOBAL_OBS.csv")

# %%
x = sc.read_h5ad("/Lymphoid.h5ad")

# %%
x.obs['leiden_annotated'].cat.categories
# Out:
# Index(['B', 'CD4T_RORC+', 'CD4T_em1', 'CD4T_em2', 'CD4T_naive', 'CD4T_reg',
#        'CD8T_GNLY_effector', 'CD8T_act_effector', 'CD8T_em1', 'CD8T_em2',
#        'CD8T_em3', 'LY1.unclassified', 'LY2.unclassified', 'NKT', 'NK_CD16hi',
#        'NK_CD16hiIFNGhi', 'NK_CD56hi', 'Plasma', 'T_prolif'],
#       dtype='object')

# %%
sc.pl.umap(x, 
          color="leiden_annotated")

# %%
[print("'", i,"'","=","'",j,"'") for i,j in zip(x.obs['leiden_annotated'].cat.categories, x.uns['leiden_annotated_colors'])]
# Out:
# ' B ' = ' #1f77b4 '
# ' CD4T_RORC+ ' = ' #ff7f0e '
# ' CD4T_em1 ' = ' #279e68 '
# ' CD4T_em2 ' = ' #d62728 '
# ' CD4T_naive ' = ' #aa40fc '
# ' CD4T_reg ' = ' #8c564b '
# ' CD8T_GNLY_effector ' = ' #e377c2 '
# ' CD8T_act_effector ' = ' #b5bd61 '
# ' CD8T_em1 ' = ' #17becf '
# ' CD8T_em2 ' = ' #aec7e8 '
# ' CD8T_em3 ' = ' #ffbb78 '
# ' LY1.unclassified ' = ' #98df8a '
# ' LY2.unclassified ' = ' #ff9896 '
# ' NKT ' = ' #c5b0d5 '
# ' NK_CD16hi ' = ' #c49c94 '
# ' NK_CD16hiIFNGhi ' = ' #f7b6d2 '
# ' NK_CD56hi ' = ' #dbdb8d '
# ' Plasma ' = ' #9edae5 '
# ' T_prolif ' = ' #ad494a '
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
x.obs.to_csv("/Lymphoid_OBS.csv")

# %%
x = sc.read_h5ad("/Myeloid.h5ad")

# %%
x.obs['leiden_annotated'].cat.categories
# Out:
# Index(['MO_CD16+', 'MO_VCAN+', 'MP_FOLR2', 'MP_ISG',
#        'MP_LYVE1hi/MHCII_intermediate', 'MP_LYVE1hi/MHCII_lo',
#        'MP_LYVE1lo/MHCII_hi', 'MP_NFKB', 'MP_OSM', 'MP_TREM2+', 'MP_prolif',
#        'MP_prolif_DCN+', 'MY1.unclassified', 'MY2.unclassified', 'cDC1',
#        'cDC2'],
#       dtype='object')

# %%
sc.pl.umap(x, 
          color="leiden_annotated")

# %%
[print("'", i,"'","=","'",j,"'") for i,j in zip(x.obs['leiden_annotated'].cat.categories, x.uns['leiden_annotated_colors'])]
# Out:
# ' MO_CD16+ ' = ' #1f77b4 '
# ' MO_VCAN+ ' = ' #ff7f0e '
# ' MP_FOLR2 ' = ' #279e68 '
# ' MP_ISG ' = ' #d62728 '
# ' MP_LYVE1hi/MHCII_intermediate ' = ' #aa40fc '
# ' MP_LYVE1hi/MHCII_lo ' = ' #8c564b '
# ' MP_LYVE1lo/MHCII_hi ' = ' #e377c2 '
# ' MP_NFKB ' = ' #b5bd61 '
# ' MP_OSM ' = ' #17becf '
# ' MP_TREM2+ ' = ' #aec7e8 '
# ' MP_prolif ' = ' #ffbb78 '
# ' MP_prolif_DCN+ ' = ' #98df8a '
# ' MY1.unclassified ' = ' #ff9896 '
# ' MY2.unclassified ' = ' #c5b0d5 '
# ' cDC1 ' = ' #c49c94 '
# ' cDC2 ' = ' #f7b6d2 '
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
x.obs.to_csv("/Myeloid_OBS.csv")

# %%
x=sc.read_h5ad("/Vascular.h5ad")

# %%
[print("'", i,"'","=","'",j,"'") for i,j in zip(x.obs['leiden_annotated'].cat.categories, x.uns['leiden_annotated_colors'])]
# Out:
# ' Cap EC1 ' = ' #1f77b4 '
# ' Cap EC2 ' = ' #ff7f0e '
# ' Cap EC3 ' = ' #279e68 '
# ' EC arterial ' = ' #d62728 '
# ' EC venous ' = ' #aa40fc '
# ' PC1 ' = ' #8c564b '
# ' PC2 ' = ' #e377c2 '
# ' PC3 ' = ' #b5bd61 '
# ' PC4 ' = ' #17becf '
# ' SMC1.1 ' = ' #aec7e8 '
# ' SMC1.2 ' = ' #ffbb78 '
# [None, None, None, None, None, None, None, None, None, None, None]

# %%
x.obs.to_csv("/Vascular_OBS.csv")

# %%
x = sc.read_h5ad("/CM.h5ad")

# %%
x.obs#['leiden_annotated'].cat.categories
# Out:
#                                                Sample batch  \
# AAACCCACACTATGTG-BS_H35_LV_premrna  BS_H35_LV_premrna     0
# AAACCCATCAGACCGC-BS_H35_LV_premrna  BS_H35_LV_premrna     0
# AAACCCATCTGACAGT-BS_H35_LV_premrna  BS_H35_LV_premrna     0
# AAACCCATCTGGCCTT-BS_H35_LV_premrna  BS_H35_LV_premrna     0
# AAACGAAAGGTAGTAT-BS_H35_LV_premrna  BS_H35_LV_premrna     0
# ...                                               ...   ...
# TTGACCCTCGGCTGAC-CVK0473_premrna      CVK0473_premrna     3
# TTGTTTGAGAATTTGG-CVK0473_premrna      CVK0473_premrna     3
# TTTCATGGTCGCGGTT-CVK0473_premrna      CVK0473_premrna     3
# TTTGATCCACAGCCAC-CVK0473_premrna      CVK0473_premrna     3
# TTTGATCCAGCTGTCG-CVK0473_premrna      CVK0473_premrna     3
#
#                                                                Barcode Region  \
# AAACCCACACTATGTG-BS_H35_LV_premrna  AAACCCACACTATGTG-BS_H35_LV_premrna     LV
# AAACCCATCAGACCGC-BS_H35_LV_premrna  AAACCCATCAGACCGC-BS_H35_LV_premrna     LV
# ...

# %%
sc.pl.umap(x, 
          color="leiden_annotated")

# %%
[print("'", i,"'","=","'",j,"'") for i,j in zip(x.obs['leiden_annotated'].cat.categories, x.uns['leiden_annotated_colors'])]
# Out:
# ' vCM1 ' = ' #1f77b4 '
# ' vCM1.1 ' = ' #ff7f0e '
# ' vCM1.2 ' = ' #279e68 '
# ' vCM1.3 ' = ' #d62728 '
# ' vCM2 ' = ' #aa40fc '
# ' vCM3 ' = ' #8c564b '
# ' vCM4 ' = ' #e377c2 '
# ' vCM5 ' = ' #b5bd61 '
# ' vCM disease ' = ' #17becf '
# [None, None, None, None, None, None, None, None, None]

# %%
x.obs.to_csv("/CM_OBS.csv")

# %%
x=sc.read_h5ad("/FB.h5ad")

# %%
[print("'", i,"'","=","'",j,"'") for i,j in zip(x.obs['leiden_annotated'].cat.categories, x.uns['leiden_annotated_colors'])]
# Out:
# ' vFB1.0 ' = ' #1f77b4 '
# ' vFB1.0_migrating ' = ' #ff7f0e '
# ' vFB1.1 ' = ' #279e68 '
# ' vFB2 ' = ' #d62728 '
# ' vFB3 ' = ' #aa40fc '
# ' vFB4 ' = ' #8c564b '
# ' vFB_ISG ' = ' #e377c2 '
# [None, None, None, None, None, None, None]

# %%
x.obs.to_csv("/FB_OBS.csv")
